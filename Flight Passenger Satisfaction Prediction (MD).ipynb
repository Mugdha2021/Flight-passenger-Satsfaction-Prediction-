# %% [markdown]
# # Company Introduction
# Your client for this project is an **FlyHigh - an Airline Company.**
#
# - Due to fierce competition in the airline industry, the airline company needs to focus on the passenger’s experience and satisfaction.
# - Customer feedback, in particular, is critical since it is an outcome measurement for business performance.
# - So, they need to analyze the data of the passenger's travel history.
# - One of the key measurements in this process is whether the passenger feels satisfied or not.
#
# ## Current Scenario
# - Currently, they have a manual process to analyze the customer satisfaction based on the number of feedback and complaint mail that they receive.

# %% [markdown]
# # Problem Statement
#
# The current process suffers from the following problems:
#
# - Analyzing the data of passengers manually and to understand whether a passenger is satisfied or not is a tedious task.
# - This process needs to be repeated every time they receive some feedback.
# - The company has hired you as data science consultants.
# - They want to automate the process of predicting the passenger satisfaction based on the travel history data collected by the airline company.
#
# ## Your Role
# - You are given a dataset containing the answer of different questions asked as the feedback.
# - Your task is to build a classification model using the dataset.
# - Because there was no machine learning model for this problem in the company, you don’t have a quantifiable win condition.
# - You need to build the best possible model.
#
# ## Project Deliverables
# - Deliverable: Predict whether the customer is satisfied or not..
# - Machine Learning Task: **Classification**
# - Target Variable: **satisfaction**
# - Win Condition: N/A (best possible model)
#
# ## Evaluation Metric
# The model evaluation will be based on the **Accuracy score.**

# %% [markdown]
# # Preoject Information
#
# - The dataset consists of information of passenger boarding and deboarding information and the services provided during the travel in flight.
#
# - The column satisfaction is also present in the dataset which is a measure of the overall satisfaction.
#
# - This is the data that we have to predict for future samples.
#
#
# - The dataset is divided into two parts: **Train, and Test sets.**
#
# # Train Set:
# -  83123 rows and 24 columns.
# - **satisfaction**  is the target variable.
#
# # Test Set:
# - 20781 rows and 23 columns.
# - The test set doesn’t contain the satisfaction column.
# - It needs to be predicted for the test set.

# %% [markdown]
# # Dataset Description
#
# - The dataset has following columns-
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01|Id| Unique Id|
# |02|Gender| Gender of the Passenger|
# |03|Customer Type| If the customer is loyal or disloyal|
# |04|Age| Age of the customer|
# |05|Type of Travel| If the travel is for a business or a personal purpose|
# |06|Class| Class of the aircraft in which the customer is travelling|
# |07|Flight Distance| Distance covered by the flight |
# |08|Inflight wifi service| If there is inflight wifi service or not|
# |09|Departure/Arrival time convenient| Rating by the customer for Departure/Arrival Time|
# |10|Ease of Online booking| Rating by the customer for this facility|
# |11|Gate location| Rating by the customer for this facility|
# |12|Food and drink| Rating by the customer for this facility|
# |13|Online boarding| Rating by the customer for this facility|
# |14|Seat comfort| Rating by the customer for this facility|
# |15|Inflight entertainment|Rating by the customer for this facility|
# |16|On-board service| Rating by the customer for this facility|
# |17|Leg room service| Rating by the customer for this facility|
# |18|Baggage handling| Rating by the customer for this facility |
# |19|Checkin service| Rating by the customer for this facility |
# |20|Inflight service| Rating by the customer for this facility|
# |21|Cleanliness|  Rating by the customer for this facility|
# |22|Departure Delay in Minutes| Rating by the customer for this facility|
# |23|Arrival Delay in Minutes| Rating by the customer for this facility|
# |24|satisfaction| If the passenger is satisfied or not|

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %% [markdown]
# # Knowing the Dataset

# %%
df = pd.read_csv('../Flight-Passenger-Satisfaction-Prediction/cust_train.csv')

# %%
df
# Out:
#           id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0      51032  Female     Loyal Customer   30  Personal Travel       Eco
# 1      54504  Female     Loyal Customer   51  Business travel       Eco
# 2      13387    Male  disloyal Customer   27  Business travel       Eco
# 3      17388  Female     Loyal Customer   52  Business travel  Business
# 4      91598  Female  disloyal Customer   15  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 83118  94444  Female     Loyal Customer   52  Business travel  Business
# 83119  68253  Female     Loyal Customer   44  Personal Travel       Eco
# 83120   1373    Male     Loyal Customer   46  Business travel  Business
# 83121  86180  Female  disloyal Customer   37  Business travel  Business
# 83122  19843  Female     Loyal Customer   23  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 0                  193                      3
# ...

# %% [markdown]
# # EDA
#
#  ## - General interpretation of the dataset

# %%
print('Shape of the Dataset: ', df.shape)
df.head()
# Out:
# Shape of the Dataset:  (83123, 24)
#       id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0  51032  Female     Loyal Customer   30  Personal Travel       Eco
# 1  54504  Female     Loyal Customer   51  Business travel       Eco
# 2  13387    Male  disloyal Customer   27  Business travel       Eco
# 3  17388  Female     Loyal Customer   52  Business travel  Business
# 4  91598  Female  disloyal Customer   15  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              193                      3                                  4
# 1              925                      2                                  1
# 2              505                      0                                  0
# 3             2953                      2                                  2
# 4             1352                      4                                  4
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83123 entries, 0 to 83122
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 83123 non-null  int64
#  1   Gender                             83123 non-null  object
#  2   Customer Type                      83123 non-null  object
#  3   Age                                83123 non-null  int64
#  4   Type of Travel                     83123 non-null  object
#  5   Class                              83123 non-null  object
#  6   Flight Distance                    83123 non-null  int64
#  7   Inflight wifi service              83123 non-null  int64
#  8   Departure/Arrival time convenient  83123 non-null  int64
#  9   Ease of Online booking             83123 non-null  int64
#  10  Gate location                      83123 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   id           Age  Flight Distance  Inflight wifi service  \
# count   83123.000000  83123.000000     83123.000000           83123.000000
# mean    64971.539574     39.351106      1190.686753               2.732553
# std     37465.886717     15.099487       998.640016               1.329950
# min         1.000000      7.000000        31.000000               0.000000
# 25%     32552.500000     27.000000       413.000000               2.000000
# 50%     64864.000000     40.000000       844.000000               3.000000
# 75%     97430.500000     51.000000      1744.000000               4.000000
# max    129880.000000     85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       83123.000000            83123.000000
# mean                            3.062269                2.756385
# std                             1.526983                1.401047
# ...

# %%
df.describe(include = object)
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count    83123           83123            83123     83123
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     42117           67915            57310     39691
#
#                    satisfaction
# count                     83123
# unique                        2
# top     neutral or dissatisfied
# freq                      47004

# %%
df.nunique()
# Out:
# id                                   83123
# Gender                                   2
# Customer Type                            2
# Age                                     75
# Type of Travel                           2
# Class                                    3
# Flight Distance                       3769
# Inflight wifi service                    6
# Departure/Arrival time convenient        6
# Ease of Online booking                   6
# Gate location                            6
# Food and drink                           6
# Online boarding                          6
# Seat comfort                             6
# Inflight entertainment                   6
# On-board service                         6
# Leg room service                         6
# Baggage handling                         5
# Checkin service                          6
# Inflight service                         6
# Cleanliness                              6
# Departure Delay in Minutes             419
# ...

# %%
print('Duplicated values present in the dataset: ', df.duplicated().any())    # Checking Duplicated Values
# Out:
# Duplicated values present in the dataset:  False

# %%
df.isnull().sum()             # Missing values in the dataset
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             251
# ...

# %% [markdown]
# # Examining Target Variable

# %%
df['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    47004
# satisfied                  36119
# Name: satisfaction, dtype: int64

# %%
df['satisfaction'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', figsize = (10,8), cmap = 'Set3')
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %% [markdown]
# # Data handling
#
#  - 251 Missing values in the feature 'Arrival Delay in Minutes'
#  - we will fill those values with mean

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean())

# %% [markdown]
# - No missing value in the dataset
# - No Duplicated value in the dataset

# %% [markdown]
# # EDA

# %%
df['Gender'].value_counts()
# Out:
# Female    42117
# Male      41006
# Name: Gender, dtype: int64

# %%
df['Customer Type'].value_counts()
# Out:
# Loyal Customer       67915
# disloyal Customer    15208
# Name: Customer Type, dtype: int64

# %%
df['Class'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', figsize = (10,8), cmap = 'Set2')
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
df['Type of Travel'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Label Encoding of Categorical variables

# %%
df_num = df.select_dtypes(include = ['int64','float64'])
df_cat = df.drop(df_num, axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df_cat = df_cat.apply(lb.fit_transform)

# %%
df_train = pd.concat([df_num, df_cat], axis = 1)

# %%
df_train = df_train[['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
       'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       'satisfaction']]

# %%
df_train.head()
# Out:
#       id  Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0  51032       0              0   30               1      1              193
# 1  54504       0              0   51               0      1              925
# 2  13387       1              1   27               0      1              505
# 3  17388       0              0   52               0      0             2953
# 4  91598       0              1   15               0      1             1352
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      2                                  1
# 2                      0                                  0
# 3                      2                                  2
# 4                      4                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %% [markdown]
# # Feature Extraction & Model Selection

# %%
df_train_features = df_train.drop(['satisfaction'], axis = 1)
df_train_target = df_train['satisfaction']

# %%
print('Shape of features dataset: ', df_train_features.shape)
print('Shape of target dataset: ', df_train_target.shape)
# Out:
# Shape of features dataset:  (83123, 23)
# Shape of target dataset:  (83123,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train_features, df_train_target, test_size = 0.2, random_state = 4)

# %%
print('Shape of x train: ', X_train.shape)
print('Shape of x test: ', X_test.shape)
print('Shape of y train: ', y_train.shape)
print('Shape of y test: ', y_test.shape)
# Out:
# Shape of x train:  (66498, 23)
# Shape of x test:  (16625, 23)
# Shape of y train:  (66498,)
# Shape of y test:  (16625,)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
numerical_features = X_train[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']].columns
numerical_features
# Out:
# Index(['Age', 'Flight Distance', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
X_train[numerical_features] = sc.fit_transform(X_train[numerical_features])

# %%
X_test[numerical_features] = sc.transform(X_test[numerical_features])

# %%
X_train.head()
# Out:
#            id  Gender  Customer Type       Age  Type of Travel  Class  \
# 50991  104146       1              0  0.437964               0      0
# 23496   45243       0              0  1.033127               1      1
# 23875   54369       0              1 -1.149136               0      1
# 64665   31492       0              0  0.504094               0      0
# 41388  125419       1              0  1.165386               0      0
#
#        Flight Distance  Inflight wifi service  \
# 50991        -0.841797                      5
# 23496        -0.176802                      2
# 23875         0.045530                      5
# 64665         1.080078                      1
# 41388        -0.455219                      1
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 50991                                  5                       5  ...
# 23496                                  1                       2  ...
# ...

# %%
X_test.head()
# Out:
#           id  Gender  Customer Type       Age  Type of Travel  Class  \
# 77549  75705       0              0  0.371835               0      0
# 57218  72777       0              0  0.041189               0      0
# 79385  64046       1              0  1.297644               0      1
# 65044   7096       1              1  1.694419               0      1
# 33793  10597       1              0  0.768610               0      0
#
#        Flight Distance  Inflight wifi service  \
# 77549         0.745578                      3
# 57218         1.769109                      5
# 79385        -0.270943                      2
# 65044        -1.034085                      3
# 33793        -0.761677                      5
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 77549                                  5                       5  ...
# 57218                                  5                       1  ...
# ...

# %% [markdown]
# # Building the Model
#
# - using Logistic regression, Decision tree, Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
logreg = LogisticRegression()
d_tree = DecisionTreeClassifier(criterion = 'entropy', max_leaf_nodes=10, max_features= "sqrt", max_depth=12, min_samples_split=5, min_samples_leaf=4)

# %%
from sklearn.model_selection import GridSearchCV 
grid = {        'n_estimators': [10, 20, 40, 60, 100, 150, 200],
                'max_features': ['auto', 'sqrt'],
                'max_depth': [2, 3, 5, 10, 20],
                'bootstrap': [True, False]
                }
rf_clf = RandomForestClassifier()
rf_random = GridSearchCV(estimator = rf_clf, param_grid = grid, cv = 3, verbose=1, n_jobs = -1)
rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 140 candidates, totalling 420 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed: 16.3min finished
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [10, 20, 40, 60, 100, 150, 200]},
#              verbose=1)

# %%
print('Logistic Regression: ', logreg.fit(X_train, y_train))
print('Decision Tree: ', d_tree.fit(X_train, y_train))
#print('Random Forest: ', rf_random.fit(X_train, y_train))
# Out:
# Logistic Regression:  LogisticRegression()
# Decision Tree:  DecisionTreeClassifier(criterion='entropy', max_depth=12, max_features='sqrt',
#                        max_leaf_nodes=10, min_samples_leaf=4,
#                        min_samples_split=5)

# %%
pred_lr = logreg.predict(X_test)
pred_dt = d_tree.predict(X_test)
pred_rf = rf_random.predict(X_test)

# %% [markdown]
# # Training with Logistic Regression

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# %%
pred_train = logreg.predict(X_train)

# %%
print('Accuracy Score of trained set: ',accuracy_score(pred_train, y_train))
print('Accuracy Score of test set: ',accuracy_score(pred_lr, y_test))
print('ROC area under curve: ',roc_auc_score(y_test, pred_lr))
# Out:
# Accuracy Score of trained set:  0.5646786369514872
# Accuracy Score of test set:  0.5686616541353383
# ROC area under curve:  0.5

# %%
print(classification_report(pred_lr, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73     16625
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.57     16625
#    macro avg       0.50      0.28      0.36     16625
# weighted avg       1.00      0.57      0.73     16625

# %%
print('LOGISTIC REGRESSION: ')
print ('The Accuracy Score is: ',accuracy_score(pred_lr, y_test))
# Out:
# LOGISTIC REGRESSION:
# The Accuracy Score is:  0.5686616541353383

# %% [markdown]
# # Training using Decision Tree

# %%
pred_dt_train = d_tree.predict(X_train)

# %%
print('Accuracy Score of trained set: ',accuracy_score(pred_dt_train, y_train))
print('Accuracy Score of test set: ',accuracy_score(pred_dt, y_test))
print('ROC area under curve: ',roc_auc_score(y_test, pred_dt))
# Out:
# Accuracy Score of trained set:  0.8584318325363168
# Accuracy Score of test set:  0.8539548872180451
# ROC area under curve:  0.8513499313234731

# %%
print(classification_report(pred_dt, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      9430
#            1       0.83      0.83      0.83      7195
#
#     accuracy                           0.85     16625
#    macro avg       0.85      0.85      0.85     16625
# weighted avg       0.85      0.85      0.85     16625

# %%
print('DECISION TREE: ')
print ('The Accuracy Score is: ',accuracy_score(pred_dt, y_test))
# Out:
# DECISION TREE:
# The Accuracy Score is:  0.8539548872180451

# %% [markdown]
# # Training using Random Forest

# %%
pred_rf_train = rf_random.predict(X_train)

# %%
print('Accuracy Score of trained set: ',accuracy_score(pred_rf_train, y_train))
print('Accuracy Score of test set: ',accuracy_score(pred_rf, y_test))
print('ROC area under curve: ',roc_auc_score(y_test, pred_rf))
# Out:
# Accuracy Score of trained set:  0.9977593311077025
# Accuracy Score of test set:  0.9628270676691729
# ROC area under curve:  0.9601594353323007

# %%
print(classification_report(pred_rf, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      9686
#            1       0.94      0.97      0.96      6939
#
#     accuracy                           0.96     16625
#    macro avg       0.96      0.96      0.96     16625
# weighted avg       0.96      0.96      0.96     16625

# %%
print('RANDOM FOREST: ')
print ('The Accuracy Score is: ',accuracy_score(pred_rf, y_test))
# Out:
# RANDOM FOREST:
# The Accuracy Score is:  0.9628270676691729

# %% [markdown]
# # Working on Test dataset

# %%
df_test = pd.read_csv('../Flight-Passenger-Satisfaction-Prediction/cust_test.csv')

# %%
print('Shape of Test set: ', df_test.shape)
df_test
# Out:
# Shape of Test set:  (20781, 23)
#            id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0       23509    Male     Loyal Customer   41  Business travel       Eco
# 1       31011  Female     Loyal Customer   18  Business travel  Business
# 2       29345  Female     Loyal Customer   13  Personal Travel  Eco Plus
# 3       50242    Male  disloyal Customer   23  Business travel       Eco
# 4       22244    Male     Loyal Customer   23  Personal Travel  Business
# ...       ...     ...                ...  ...              ...       ...
# 20776   21910    Male  disloyal Customer   26  Business travel       Eco
# 20777  107869    Male  disloyal Customer   43  Business travel  Business
# 20778   44306  Female     Loyal Customer   38  Business travel  Business
# 20779   16965    Male     Loyal Customer   53  Business travel       Eco
# 20780   75189  Female     Loyal Customer   44  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20781 entries, 0 to 20780
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 20781 non-null  int64
#  1   Gender                             20781 non-null  object
#  2   Customer Type                      20781 non-null  object
#  3   Age                                20781 non-null  int64
#  4   Type of Travel                     20781 non-null  object
#  5   Class                              20781 non-null  object
#  6   Flight Distance                    20781 non-null  int64
#  7   Inflight wifi service              20781 non-null  int64
#  8   Departure/Arrival time convenient  20781 non-null  int64
#  9   Ease of Online booking             20781 non-null  int64
#  10  Gate location                      20781 non-null  int64
# ...

# %%
df_test.isnull().sum()               # Checking missing values
# Out:
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             59
# dtype: int64

# %%
df_test['Arrival Delay in Minutes'] = df_test['Arrival Delay in Minutes'].fillna(df_test['Arrival Delay in Minutes'].mean())

# %%
df_test.isnull().sum().any()
# Out:
# False

# %%
print('Test dataset Contains Duplicate Rows?',df_test.duplicated().any())
# Out:
# Test dataset Contains Duplicate Rows? False

# %% [markdown]
# # Handling Categorical Values

# %%
df_num1 = df_test.select_dtypes(include = ['int64','float64'])
df_cat1 = df_test.drop(df_num1, axis = 1)
df_cat1 = df_cat1.apply(lb.fit_transform)

# %%
df_test1 = pd.concat([df_num1, df_cat1], axis = 1)

# %%
df_test1.head()
# Out:
#       id  Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0  23509       1              0   41               0      1              303
# 1  31011       0              0   18               0      0              391
# 2  29345       0              0   13               1      2              569
# 3  50242       1              1   23               0      1              109
# 4  22244       1              0   23               1      0               83
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  3
# 1                      1                                  5
# 2                      2                                  4
# 3                      1                                  0
# 4                      4                                  5
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# ...

# %%
df_test1 = df_test1[['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
       'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes',
       'Arrival Delay in Minutes']]

# %% [markdown]
# # Scaling

# %%
numerical_features
# Out:
# Index(['Age', 'Flight Distance', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df_test1[numerical_features]= sc.fit_transform(df_test1[numerical_features])
df_test1.head()

#-------------Test dataset is ready for Machine Learning------------------#
# Out:
#       id  Gender  Customer Type       Age  Type of Travel  Class  \
# 0  23509       1              0  0.099228               0      1
# 1  31011       0              0 -1.416306               0      0
# 2  29345       0              0 -1.745770               1      2
# 3  50242       1              1 -1.086842               0      1
# 4  22244       1              0 -1.086842               1      0
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0        -0.889376                      5                                  3
# 1        -0.800589                      1                                  5
# 2        -0.620998                      2                                  4
# 3        -1.085111                      1                                  0
# 4        -1.111343                      4                                  5
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# ...

# %% [markdown]
# # Predicting Flight Passenger Satisfaction

# %%
y_pred_test_final = rf_random.predict(df_test1)

# %%
y_pred_test_final
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %% [markdown]
# # Converting Array to Dataset

# %%
y_pred_test_final = pd.DataFrame(y_pred_test_final)

# %%
y_pred_test_final
# Out:
#        0
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 20776  0
# 20777  0
# 20778  1
# 20779  0
# 20780  1
#
# [20781 rows x 1 columns]

# %%
data_submission = df_test['id']

# %% [markdown]
# # Predicting Submission file

# %%
submission_file =  pd.concat([data_submission,y_pred_test_final], axis = 1)

# %%
submission_file
# Out:
#            id  0
# 0       23509  1
# 1       31011  0
# 2       29345  0
# 3       50242  0
# 4       22244  0
# ...       ... ..
# 20776   21910  0
# 20777  107869  0
# 20778   44306  1
# 20779   16965  0
# 20780   75189  1
#
# [20781 rows x 2 columns]

# %% [markdown]
# # Saving Flight Passenger Satisfaction Prediction in Excel file

# %%
submission_file.to_csv('flight_passenger_satisfaction_prediction_submission.csv', header=False, index=False)
